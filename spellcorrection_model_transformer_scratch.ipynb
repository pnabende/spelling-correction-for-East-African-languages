# %% [markdown]
# <a href="https://colab.research.google.com/github/pnabende/spelling-correction-for-East-African-languages/blob/master/spellcorrection_model_transformer_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the necessary packages

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# Open the google drive folder that has the datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load the datasets

# %%
train_data = pd.read_csv('/content/drive/MyDrive/research/spelling-correction/data/sampled-10000train-1000test/train-10000-luganda-double-tripple-errors.csv')
test_data = pd.read_csv('/content/drive/MyDrive/research/spelling-correction/data/sampled-10000train-1000test/test-1000-single-A-error.csv')

# %% [markdown]
# Ensure the data is only of string type

# %%
train_data['incorrect_word'] = train_data['incorrect_word'].astype(str)
train_data['correct_word'] = train_data['correct_word'].astype(str)
test_data['incorrect_word'] = test_data['incorrect_word'].astype(str)
test_data['correct_word'] = test_data['correct_word'].astype(str)

# %% [markdown]
# Tokenize

# %%
# Step 2: Tokenization using Tokenizer (character-level, case-sensitive)
tokenizer = Tokenizer(char_level=True, lower=False)
tokenizer.fit_on_texts(train_data['incorrect_word'] + train_data['correct_word'])

train_seq_incorrect = tokenizer.texts_to_sequences(train_data['incorrect_word'])
train_seq_correct = tokenizer.texts_to_sequences(train_data['correct_word'])
test_seq_incorrect = tokenizer.texts_to_sequences(test_data['incorrect_word'])
test_seq_correct = tokenizer.texts_to_sequences(test_data['correct_word'])

# %% [markdown]
# Pad sequences to maximum length

# %%
# Padding sequences to the maximum length
max_length = max(len(seq) for seq in train_seq_incorrect + test_seq_incorrect + train_seq_correct + test_seq_correct)

train_input_ids = pad_sequences(train_seq_incorrect, maxlen=max_length, padding='post')
train_labels = pad_sequences(train_seq_correct, maxlen=max_length, padding='post')
test_input_ids = pad_sequences(test_seq_incorrect, maxlen=max_length, padding='post')
test_labels = pad_sequences(test_seq_correct, maxlen=max_length, padding='post')

# %% [markdown]
# Build the character-level transformer

# %%
# Step 3: Build the character-level transformer model
num_chars = len(tokenizer.word_index) + 1
embedding_dim = 64
num_heads = 4
dff = 128
num_encoder_layers = 2

def positional_encoding(max_position, d_model):
    angle_rates = 1 / np.power(10000, (2 * (np.arange(d_model) // 2)) / np.float32(d_model))
    angle_rads = np.arange(max_position)[:, np.newaxis] * angle_rates[np.newaxis, :]
    sines = np.sin(angle_rads[:, 0::2])
    cosines = np.cos(angle_rads[:, 1::2])
    pos_encoding = np.concatenate([sines, cosines], axis=-1)
    return tf.constant(pos_encoding, dtype=tf.float32)

class EncoderBlock(tf.keras.layers.Layer):
    def __init__(self, embedding_dim, num_heads, dff, rate=0.1):
        super(EncoderBlock, self).__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)
        self.ffn = tf.keras.Sequential([tf.keras.layers.Dense(dff, activation='relu'), tf.keras.layers.Dense(embedding_dim)])
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.mha(inputs, inputs, inputs)  # Self-attention
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)  # Residual connection and layer normalization

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # Residual connection and layer normalization

        return out2

class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, embedding_dim, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()
        self.embedding_dim = embedding_dim
        self.embedding = tf.keras.layers.Embedding(input_vocab_size, embedding_dim)
        self.pos_encoding = positional_encoding(maximum_position_encoding, embedding_dim)
        self.enc_layers = [EncoderBlock(embedding_dim, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, inputs, training):
        seq_length = tf.shape(inputs)[1]
        mask = tf.math.logical_not(tf.math.equal(inputs, 0))
        mask = tf.expand_dims(mask, -1)
        inputs = self.embedding(inputs)  # Adding embedding
        inputs *= tf.math.sqrt(tf.cast(self.embedding_dim, tf.float32))
        # Expanding the positional encoding along the batch dimension
        pos_encoding = tf.tile(tf.expand_dims(self.pos_encoding, axis=0), [tf.shape(inputs)[0], 1, 1])
        inputs += pos_encoding[:, :seq_length, :]
        inputs = self.dropout(inputs, training=training)
        for enc_layer in self.enc_layers:
            inputs = enc_layer(inputs, training)  # Remove 'mask' from the arguments

        return inputs

# %% [markdown]
# Build and compile the transformer-based spelling correction model

# %%
# Step 4: Build and compile the transformer-based spelling correction model
num_encoder_layers = 2
input_ids = Input(shape=(max_length,), dtype='int32')
encoder_output = Encoder(num_encoder_layers, embedding_dim, num_heads, dff, num_chars, max_length)(input_ids)
output = Dense(num_chars, activation='softmax')(encoder_output)

model = Model(inputs=input_ids, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %% [markdown]
# Train the model

# %%
# Step 5: Train the model
model.fit(train_input_ids, train_labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 33s 45ms/step - loss: 0.3594
# Epoch 2/10
# 625/625 [==============================] - 28s 44ms/step - loss: 0.2396
# Epoch 3/10
# 625/625 [==============================] - 27s 43ms/step - loss: 0.2113
# Epoch 4/10
# 625/625 [==============================] - 28s 44ms/step - loss: 0.1970
# Epoch 5/10
# 625/625 [==============================] - 27s 43ms/step - loss: 0.1879
# Epoch 6/10
# 625/625 [==============================] - 27s 44ms/step - loss: 0.1810
# Epoch 7/10
# 625/625 [==============================] - 27s 44ms/step - loss: 0.1762
# Epoch 8/10
# 625/625 [==============================] - 27s 43ms/step - loss: 0.1709
# Epoch 9/10
# 625/625 [==============================] - 28s 44ms/step - loss: 0.1690
# Epoch 10/10
# 625/625 [==============================] - 27s 43ms/step - loss: 0.1654

# %% [markdown]
# Evaluate the model

# %%
# Step 6: Evaluation
predictions = model.predict(test_input_ids)
decoded_predictions = tokenizer.sequences_to_texts(np.argmax(predictions, axis=-1))
decoded_predictions_no_spaces = [''.join(prediction.split()) for prediction in decoded_predictions]
# Calculate accuracy
correct_predictions = np.array(test_data['correct_word']) == np.array(decoded_predictions_no_spaces)
accuracy = np.mean(correct_predictions)

print(f"Accuracy: {accuracy:.2f}")
# Out:
# 32/32 [==============================] - 1s 23ms/step
# Accuracy: 0.14

# %% [markdown]
# Show the predicted corrections

# %%
# Show the predicted corrections alongside the original incorrect words and target correct words
for idx, (incorrect_words, target_words, predicted_word, is_correct) in enumerate(zip(test_data['incorrect_word'], test_data['correct_word'], decoded_predictions_no_spaces, correct_predictions)):
    print(f"Example {idx + 1}:")
    print(f"Incorrect Word(s): {incorrect_words}")
    print(f"Target Correct Word(s): {target_words}")
    print(f"Predicted Word(s): {predicted_word}")
    print(f"Is Correct: {is_correct}")
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# Is Correct: False
#
# Example 168:
# Incorrect Word(s): apalituuka
# Target Correct Word(s): akalituuka
# Predicted Word(s): alalituuka
# Is Correct: False
#
# Example 169:
# Incorrect Word(s): enayumbi
# Target Correct Word(s): enayumba
# Predicted Word(s): enayumbi
# Is Correct: False
#
# Example 170:
# Incorrect Word(s): boonozna
# Target Correct Word(s): boonoona
# Predicted Word(s): boonoana
# Is Correct: False
#
# Example 171:
# Incorrect Word(s): siyimiridde
# Target Correct Word(s): kiyimiridde
# Predicted Word(s): siyimiridde
# Is Correct: False
#
# Example 172:
# Incorrect Word(s): tokuŋŋabayanga
# Target Correct Word(s): tokuŋŋaaayanga
# Predicted Word(s): tokuŋŋabayanga
# Is Correct: False
#
# Example 173:
# Incorrect Word(s): aresusito
# Target Correct Word(s): amesusito
# Predicted Word(s): atesusito
# Is Correct: False
#
# Example 174:
# Incorrect Word(s): adunoni
# Target Correct Word(s): alunoni
# Predicted Word(s): adunoni
# Is Correct: False
#
# Example 175:
# Incorrect Word(s): baddukangra
# Target Correct Word(s): baddukanira
# Predicted Word(s): baddukangra
# Is Correct: False
#
# Example 176:
# Incorrect Word(s): nzuŋŋaanyiza
# Target Correct Word(s): nkuŋŋaanyiza
# Predicted Word(s): nzuŋŋaanyiza
# Is Correct: False
#
# Example 177:
# Incorrect Word(s): muwedde
# Target Correct Word(s): kuwedde
# Predicted Word(s): muwedde
# Is Correct: False
#
# Example 178:
# Incorrect Word(s): omuyisulm
# Target Correct Word(s): omuyisuli
# Predicted Word(s): omuyisuli
# Is Correct: True
#
# Example 179:
# Incorrect Word(s): akyetikka
# Target Correct Word(s): alyetikka
# Predicted Word(s): akyetikka
# Is Correct: False
#
# Example 180:
# Incorrect Word(s): bbaave
# Target Correct Word(s): bbaawe
# Predicted Word(s): bbaave
# Is Correct: False
#
# Example 181:
# Incorrect Word(s): okukgusakuusa
# Target Correct Word(s): okukuusakuusa
# Predicted Word(s): okukgusakuusa
# Is Correct: False
#
# Example 182:
# Incorrect Word(s): ziggwaawoa
# Target Correct Word(s): ziggwaawo
# Predicted Word(s): ziggwaaaoa
# Is Correct: False
#
# Example 183:
# Incorrect Word(s): kuziywzibwa
# Target Correct Word(s): kuziyizibwa
# Predicted Word(s): kuziyazibwa
# Is Correct: False
#
# Example 184:
# Incorrect Word(s): gariba
# Target Correct Word(s): galiba
# Predicted Word(s): gatiba
# Is Correct: False
#
# Example 185:
# Incorrect Word(s): kyAomhana
# Target Correct Word(s): kyAomwana
# Predicted Word(s): kyAomuana
# Is Correct: False
#
# Example 186:
# Incorrect Word(s): tebaagala
# Target Correct Word(s): tebaagala
# Predicted Word(s): tebaagala
# Is Correct: True
#
# Example 187:
# Incorrect Word(s): uri
# Target Correct Word(s): uzi
# Predicted Word(s): iri
# Is Correct: False
#
# Example 188:
# Incorrect Word(s): okusagnuuka
# Target Correct Word(s): okusaanuuka
# Predicted Word(s): okusanguuka
# Is Correct: False
#
# Example 189:
# Incorrect Word(s): ganera
# Target Correct Word(s): gamera
# Predicted Word(s): gabera
# Is Correct: False
#
# Example 190:
# Incorrect Word(s): nAoluzzir
# Target Correct Word(s): nAoluzzi
# Predicted Word(s): nAoluzzie
# Is Correct: False
#
# Example 191:
# Incorrect Word(s): emivunbo
# Target Correct Word(s): emivumbo
# Predicted Word(s): emivungo
# Is Correct: False
#
# Example 192:
# Incorrect Word(s): abiti
# Target Correct Word(s): abiri
# Predicted Word(s): abiri
# Is Correct: True
#
# Example 193:
# Incorrect Word(s): nAktunuulira
# Target Correct Word(s): nAatunuulira
# Predicted Word(s): nAotunuulira
# Is Correct: False
#
# Example 194:
# Incorrect Word(s): okutuukiriza
# Target Correct Word(s): okutuukiriza
# Predicted Word(s): okutuukiriza
# Is Correct: True
#
# Example 195:
# Incorrect Word(s): bto
# Target Correct Word(s): byo
# Predicted Word(s): nto
# Is Correct: False
#
# Example 196:
# Incorrect Word(s): ndimola
# Target Correct Word(s): ndikola
# Predicted Word(s): ndimola
# Is Correct: False
#
# Example 197:
# Incorrect Word(s): yaliro
# Target Correct Word(s): yaliko
# Predicted Word(s): yaliro
# Is Correct: False
#
# Example 198:
# Incorrect Word(s): akwetikka
# Target Correct Word(s): okwetikka
# Predicted Word(s): akwetikka
# Is Correct: False
#
# Example 199:
# Incorrect Word(s): kyenma
# Target Correct Word(s): kyenva
# Predicted Word(s): kyenna
# Is Correct: False
#
# Example 200:
# Incorrect Word(s): afusirira
# Target Correct Word(s): afukirira
# Predicted Word(s): afusirira
# Is Correct: False
#
# Example 201:
# Incorrect Word(s): baanuula
# Target Correct Word(s): baasuula
# Predicted Word(s): baanuula
# Is Correct: False
#
# Example 202:
# Incorrect Word(s): omujjukizar
# Target Correct Word(s): omujjukiza
# Predicted Word(s): omujjukizae
# Is Correct: False
#
# Example 203:
# Incorrect Word(s): febbeeka
# Target Correct Word(s): lebbeeka
# Predicted Word(s): tebbeeka
# Is Correct: False
#
# Example 204:
# Incorrect Word(s): bwAeyawukanfmu
# Target Correct Word(s): bwAeyawukanamu
# Predicted Word(s): bwAeyawukangmu
# Is Correct: False
#
# Example 205:
# Incorrect Word(s): balibayitw
# Target Correct Word(s): balibayita
# Predicted Word(s): balibayira
# Is Correct: False
#
# Example 206:
# Incorrect Word(s): nAamawaggkli
# Target Correct Word(s): nAamawaggali
# Predicted Word(s): nAamawagguli
# Is Correct: False
#
# Example 207:
# Incorrect Word(s): manula
# Target Correct Word(s): tanula
# Predicted Word(s): mamula
# Is Correct: False
#
# Example 208:
# Incorrect Word(s): bAamatezka
# Target Correct Word(s): bAamateeka
# Predicted Word(s): nAamatezka
# Is Correct: False
#
# Example 209:
# Incorrect Word(s): munaawaananga
# Target Correct Word(s): munaagaananga
# Predicted Word(s): munaawaananga
# Is Correct: False
#
# Example 210:
# Incorrect Word(s): mbalaqira
# Target Correct Word(s): mbalagira
# Predicted Word(s): mbalasira
# Is Correct: False
#
# Example 211:
# Incorrect Word(s): alimuyxmusa
# Target Correct Word(s): alimuyimusa
# Predicted Word(s): alimuyamusa
# Is Correct: False
#
# Example 212:
# Incorrect Word(s): omulondb
# Target Correct Word(s): omulonde
# Predicted Word(s): omulonde
# Is Correct: True
#
# Example 213:
# Incorrect Word(s): omukadde
# Target Correct Word(s): omukadde
# Predicted Word(s): omukadde
# Is Correct: True
#
# Example 214:
# Incorrect Word(s): akAamatuta
# Target Correct Word(s): akAamafuta
# Predicted Word(s): akAamatuta
# Is Correct: False
#
# Example 215:
# Incorrect Word(s): okuliira
# Target Correct Word(s): okuliira
# Predicted Word(s): okuliira
# Is Correct: True
#
# Example 216:
# Incorrect Word(s): baffl
# Target Correct Word(s): baffe
# Predicted Word(s): baffo
# Is Correct: False
#
# Example 217:
# Incorrect Word(s): kgAempungu
# Target Correct Word(s): ngAempungu
# Predicted Word(s): kyAempungu
# Is Correct: False
#
# Example 218:
# Incorrect Word(s): zgnaatera
# Target Correct Word(s): zinaatera
# Predicted Word(s): annaatera
# Is Correct: False
#
# Example 219:
# Incorrect Word(s): nneebazanua
# Target Correct Word(s): nneebazanga
# Predicted Word(s): nneebazanya
# Is Correct: False
#
# Example 220:
# Incorrect Word(s): muddeetere
# Target Correct Word(s): mundeetere
# Predicted Word(s): muddeetere
# Is Correct: False
#
# Example 221:
# Incorrect Word(s): olunnyamba
# Target Correct Word(s): okunnyamba
# Predicted Word(s): olunnyamba
# Is Correct: False
#
# Example 222:
# Incorrect Word(s): ekitundu
# Target Correct Word(s): ekitundu
# Predicted Word(s): ekitundu
# Is Correct: True
#
# Example 223:
# Incorrect Word(s): okugibaja
# Target Correct Word(s): okugibawa
# Predicted Word(s): okugibana
# Is Correct: False
#
# Example 224:
# Incorrect Word(s): yakema
# Target Correct Word(s): bakema
# Predicted Word(s): yakema
# Is Correct: False
#
# Example 225:
# Incorrect Word(s): bukube
# Target Correct Word(s): tukube
# Predicted Word(s): bukube
# Is Correct: False
#
# Example 226:
# Incorrect Word(s): nguomuzabbibu
# Target Correct Word(s): ngAomuzabbibu
# Predicted Word(s): nguomuzangibu
# Is Correct: False
#
# Example 227:
# Incorrect Word(s): okutyk
# Target Correct Word(s): okutya
# Predicted Word(s): okutyo
# Is Correct: False
#
# Example 228:
# Incorrect Word(s): abanjaga
# Target Correct Word(s): abanyaga
# Predicted Word(s): abanjaga
# Is Correct: False
#
# Example 229:
# Incorrect Word(s): azaayp
# Target Correct Word(s): azaaye
# Predicted Word(s): azaayo
# Is Correct: False
#
# Example 230:
# Incorrect Word(s): ypzeeri
# Target Correct Word(s): yezeeri
# Predicted Word(s): yozeeri
# Is Correct: False
#
# Example 231:
# Incorrect Word(s): ngiyinza
# Target Correct Word(s): ndiyinza
# Predicted Word(s): ngiyinza
# Is Correct: False
#
# Example 232:
# Incorrect Word(s): agatambulal
# Target Correct Word(s): agatambula
# Predicted Word(s): abatambulao
# Is Correct: False
#
# Example 233:
# Incorrect Word(s): tanukufesi
# Target Correct Word(s): tanukumesi
# Predicted Word(s): tamukugesi
# Is Correct: False
#
# Example 234:
# Incorrect Word(s): eyAokwwbaza
# Target Correct Word(s): eyAokwebaza
# Predicted Word(s): eyAokwabaza
# Is Correct: False
#
# Example 235:
# Incorrect Word(s): ekfkolo
# Target Correct Word(s): ekikolo
# Predicted Word(s): ekekolo
# Is Correct: False
#
# Example 236:
# Incorrect Word(s): ngAatenoereza
# Target Correct Word(s): ngAatendereza
# Predicted Word(s): ngAatenoereza
# Is Correct: False
#
# Example 237:
# Incorrect Word(s): okundowooza
# Target Correct Word(s): okundowooza
# Predicted Word(s): okundowooza
# Is Correct: True
#
# Example 238:
# Incorrect Word(s): nAazigkibwa
# Target Correct Word(s): nAaziikibwa
# Predicted Word(s): nAazigkibwa
# Is Correct: False
#
# Example 239:
# Incorrect Word(s): yeekakaadiriza
# Target Correct Word(s): yeekakaabiriza
# Predicted Word(s): yeekakaadiriza
# Is Correct: False
#
# Example 240:
# Incorrect Word(s): enjagi
# Target Correct Word(s): enjagi
# Predicted Word(s): enjagi
# Is Correct: True
#
# Example 241:
# Incorrect Word(s): baayagada
# Target Correct Word(s): baayagala
# Predicted Word(s): baayagada
# Is Correct: False
#
# Example 242:
# Incorrect Word(s): obuwesiyopyas
# Target Correct Word(s): obuwesiyopya
# Predicted Word(s): obuwesiyolyaa
# Is Correct: False
#
# Example 243:
# Incorrect Word(s): tzyantuma
# Target Correct Word(s): teyantuma
# Predicted Word(s): tayanyuma
# Is Correct: False
#
# Example 244:
# Incorrect Word(s): ekyAomukaagao
# Target Correct Word(s): ekyAomukaaga
# Predicted Word(s): ekyAomukaagao
# Is Correct: False
#
# Example 245:
# Incorrect Word(s): ssanou
# Target Correct Word(s): ssanyu
# Predicted Word(s): ssanku
# Is Correct: False
#
# Example 246:
# Incorrect Word(s): gukuhta
# Target Correct Word(s): gukunta
# Predicted Word(s): gukunta
# Is Correct: True
#
# Example 247:
# Incorrect Word(s): kazolenaani
# Target Correct Word(s): kazalenaani
# Predicted Word(s): kazolenaani
# Is Correct: False
#
# Example 248:
# Incorrect Word(s): kinnewosi
# Target Correct Word(s): kinnerosi
# Predicted Word(s): kinnewosi
# Is Correct: False
#
# Example 249:
# Incorrect Word(s): nAanyweral
# Target Correct Word(s): nAanywera
# Predicted Word(s): nAanywerao
# Is Correct: False
#
# Example 250:
# Incorrect Word(s): nAagosamu
# Target Correct Word(s): nAagobamu
# Predicted Word(s): nAagosamu
# Is Correct: False
#
# Example 251:
# Incorrect Word(s): bwAoyaghla
# Target Correct Word(s): bwAoyagala
# Predicted Word(s): bwAoyagula
# Is Correct: False
#
# Example 252:
# Incorrect Word(s): mayuj
# Target Correct Word(s): mayu
# Predicted Word(s): mayui
# Is Correct: False
#
# Example 253:
# Incorrect Word(s): ezAatawanga
# Target Correct Word(s): ezAamawanga
# Predicted Word(s): ezAatawanga
# Is Correct: False
#
# Example 254:
# Incorrect Word(s): yAendagaato
# Target Correct Word(s): yAendagaano
# Predicted Word(s): yAendagaayo
# Is Correct: False
#
# Example 255:
# Incorrect Word(s): eggloni
# Target Correct Word(s): eguloni
# Predicted Word(s): eggloni
# Is Correct: False
#
# Example 256:
# Incorrect Word(s): yalagaawya
# Target Correct Word(s): yalagaanya
# Predicted Word(s): yalagaaaya
# Is Correct: False
#
# Example 257:
# Incorrect Word(s): kiwulipe
# Target Correct Word(s): kiwulire
# Predicted Word(s): kiwulile
# Is Correct: False
#
# Example 258:
# Incorrect Word(s): okuddlzaawo
# Target Correct Word(s): okuddizaawo
# Predicted Word(s): okuddizaawo
# Is Correct: True
#
# Example 259:
# Incorrect Word(s): nneegomva
# Target Correct Word(s): nneegomba
# Predicted Word(s): nneegomba
# Is Correct: True
#
# Example 260:
# Incorrect Word(s): kakyogeddey
# Target Correct Word(s): kakyogedde
# Predicted Word(s): kakyogedddu
# Is Correct: False
#
# Example 261:
# Incorrect Word(s): ekirtko
# Target Correct Word(s): ekiriko
# Predicted Word(s): ekiruko
# Is Correct: False
#
# Example 262:
# Incorrect Word(s): libzze
# Target Correct Word(s): libuze
# Predicted Word(s): libaze
# Is Correct: False
#
# Example 263:
# Incorrect Word(s): abakgesiga
# Target Correct Word(s): abakwesiga
# Predicted Word(s): abakgesira
# Is Correct: False
#
# Example 264:
# Incorrect Word(s): mubuulirenea
# Target Correct Word(s): mubuulirenga
# Predicted Word(s): mubuulirebwa
# Is Correct: False
#
# Example 265:
# Incorrect Word(s): aliyinzab
# Target Correct Word(s): aliyinza
# Predicted Word(s): aliyinzae
# Is Correct: False
#
# Example 266:
# Incorrect Word(s): nArkusasula
# Target Correct Word(s): nAokusasula
# Predicted Word(s): nAekusasula
# Is Correct: False
#
# Example 267:
# Incorrect Word(s): ekyAibakulu
# Target Correct Word(s): ekyAabakulu
# Predicted Word(s): ekyAobakulu
# Is Correct: False
#
# Example 268:
# Incorrect Word(s): ntafuluma
# Target Correct Word(s): naafuluma
# Predicted Word(s): ntafuluma
# Is Correct: False
#
# Example 269:
# Incorrect Word(s): tebrseereranga
# Target Correct Word(s): tebiseereranga
# Predicted Word(s): tebeseereranga
# Is Correct: False
#
# Example 270:
# Incorrect Word(s): blyonaani
# Target Correct Word(s): buyonaani
# Predicted Word(s): biyonaani
# Is Correct: False
#
# Example 271:
# Incorrect Word(s): baliweeywa
# Target Correct Word(s): baliweebwa
# Predicted Word(s): baliweebwa
# Is Correct: True
#
# Example 272:
# Incorrect Word(s): amaceeka
# Target Correct Word(s): amateeka
# Predicted Word(s): amaseeka
# Is Correct: False
#
# Example 273:
# Incorrect Word(s): nntanywegera
# Target Correct Word(s): nnaanywegera
# Predicted Word(s): nnyanywerera
# Is Correct: False
#
# Example 274:
# Incorrect Word(s): kitorgo
# Target Correct Word(s): kitoogo
# Predicted Word(s): kitigyo
# Is Correct: False
#
# Example 275:
# Incorrect Word(s): ngAomwaoa
# Target Correct Word(s): ngAomwana
# Predicted Word(s): ngAomwala
# Is Correct: False
#
# Example 276:
# Incorrect Word(s): antuuzizza
# Target Correct Word(s): antuuzizza
# Predicted Word(s): antuuzizza
# Is Correct: True
#
# Example 277:
# Incorrect Word(s): aayina
# Target Correct Word(s): nayina
# Predicted Word(s): aayina
# Is Correct: False
#
# Example 278:
# Incorrect Word(s): akunyoomyeo
# Target Correct Word(s): akunyoomye
# Predicted Word(s): akunyoomywo
# Is Correct: False
#
# Example 279:
# Incorrect Word(s): tebuliwmu
# Target Correct Word(s): tebuliimu
# Predicted Word(s): tebuliamu
# Is Correct: False
#
# Example 280:
# Incorrect Word(s): batabqlaba
# Target Correct Word(s): batabalaba
# Predicted Word(s): batabalaba
# Is Correct: True
#
# Example 281:
# Incorrect Word(s): kubalabp
# Target Correct Word(s): kubalaba
# Predicted Word(s): kubalabo
# Is Correct: False
#
# Example 282:
# Incorrect Word(s): ezaalio
# Target Correct Word(s): ezaali
# Predicted Word(s): ezaalko
# Is Correct: False
#
# Example 283:
# Incorrect Word(s): ketuba
# Target Correct Word(s): ketula
# Predicted Word(s): ketuba
# Is Correct: False
#
# Example 284:
# Incorrect Word(s): anunuoa
# Target Correct Word(s): anunula
# Predicted Word(s): amunula
# Is Correct: False
#
# Example 285:
# Incorrect Word(s): asigaddz
# Target Correct Word(s): asigadde
# Predicted Word(s): asigadda
# Is Correct: False
#
# Example 286:
# Incorrect Word(s): mmuwoqya
# Target Correct Word(s): mmuwonya
# Predicted Word(s): mmuwoaya
# Is Correct: False
#
# Example 287:
# Incorrect Word(s): anaakulzkolanga
# Target Correct Word(s): anaakulokolanga
# Predicted Word(s): anaakulakolanga
# Is Correct: False
#
# Example 288:
# Incorrect Word(s): bwAalifarnana
# Target Correct Word(s): bwAalifaanana
# Predicted Word(s): bwAalibaenana
# Is Correct: False
#
# Example 289:
# Incorrect Word(s): njAogamba
# Target Correct Word(s): ngAogamba
# Predicted Word(s): ngAogamba
# Is Correct: True
#
# Example 290:
# Incorrect Word(s): nzmyaako
# Target Correct Word(s): nziyaako
# Predicted Word(s): bamyaako
# Is Correct: False
#
# Example 291:
# Incorrect Word(s): lutabyalo
# Target Correct Word(s): lutabaalo
# Predicted Word(s): lutabyalo
# Is Correct: False
#
# Example 292:
# Incorrect Word(s): ekikondb
# Target Correct Word(s): ekikondo
# Predicted Word(s): ekikonde
# Is Correct: False
#
# Example 293:
# Incorrect Word(s): kinaakolebwabga
# Target Correct Word(s): kinaakolebwanga
# Predicted Word(s): kinaakolebwanga
# Is Correct: True
#
# Example 294:
# Incorrect Word(s): ekitowgole
# Target Correct Word(s): ekitongole
# Predicted Word(s): ekitoagole
# Is Correct: False
#
# Example 295:
# Incorrect Word(s): abamcli
# Target Correct Word(s): abamuli
# Predicted Word(s): abamali
# Is Correct: False
#
# Example 296:
# Incorrect Word(s): nAobulamub
# Target Correct Word(s): nAobulamu
# Predicted Word(s): nAobulamue
# Is Correct: False
#
# Example 297:
# Incorrect Word(s): nAokuzimuka
# Target Correct Word(s): nAokuyimuka
# Predicted Word(s): nAokuzimuka
# Is Correct: False
#
# Example 298:
# Incorrect Word(s): omanya
# Target Correct Word(s): omanyi
# Predicted Word(s): omanya
# Is Correct: False
#
# Example 299:
# Incorrect Word(s): mcggya
# Target Correct Word(s): muggya
# Predicted Word(s): meggya
# Is Correct: False
#
# Example 300:
# Incorrect Word(s): nAavvunama
# Target Correct Word(s): nAavuunama
# Predicted Word(s): nAavvunama
# Is Correct: False
#
# Example 301:
# Incorrect Word(s): tanwafa
# Target Correct Word(s): tannafa
# Predicted Word(s): tanaafa
# Is Correct: False
#
# Example 302:
# Incorrect Word(s): efoni
# Target Correct Word(s): eroni
# Predicted Word(s): eroni
# Is Correct: True
#
# Example 303:
# Incorrect Word(s): kikyalido
# Target Correct Word(s): kikyaliwo
# Predicted Word(s): kikyaliro
# Is Correct: False
#
# Example 304:
# Incorrect Word(s): olmnwe
# Target Correct Word(s): olunwe
# Predicted Word(s): olibwe
# Is Correct: False
#
# Example 305:
# Incorrect Word(s): okwambulaa
# Target Correct Word(s): okwambula
# Predicted Word(s): okwambulaa
# Is Correct: False
#
# Example 306:
# Incorrect Word(s): temuyendanga
# Target Correct Word(s): temugendanga
# Predicted Word(s): temuyendanga
# Is Correct: False
#
# Example 307:
# Incorrect Word(s): ataayingiranga
# Target Correct Word(s): anaayingiranga
# Predicted Word(s): ataayingiranga
# Is Correct: False
#
# Example 308:
# Incorrect Word(s): bwAolubrawo
# Target Correct Word(s): bwAolubaawo
# Predicted Word(s): bwAolubgawo
# Is Correct: False
#
# Example 309:
# Incorrect Word(s): kubeeranaa
# Target Correct Word(s): kubeeranga
# Predicted Word(s): kubeeranaa
# Is Correct: False
#
# Example 310:
# Incorrect Word(s): nAagdibwa
# Target Correct Word(s): nAaggibwa
# Predicted Word(s): nAagdibwa
# Is Correct: False
#
# Example 311:
# Incorrect Word(s): akgba
# Target Correct Word(s): akuba
# Predicted Word(s): akuba
# Is Correct: True
#
# Example 312:
# Incorrect Word(s): bivo
# Target Correct Word(s): biro
# Predicted Word(s): bivo
# Is Correct: False
#
# Example 313:
# Incorrect Word(s): seiriire
# Target Correct Word(s): siiriire
# Predicted Word(s): ssiriire
# Is Correct: False
#
# Example 314:
# Incorrect Word(s): owusonyiwanga
# Target Correct Word(s): omusonyiwanga
# Predicted Word(s): owusonyiwanga
# Is Correct: False
#
# Example 315:
# Incorrect Word(s): baamufumitira
# Target Correct Word(s): baamufumitira
# Predicted Word(s): baamufumirira
# Is Correct: False
#
# Example 316:
# Incorrect Word(s): anaawonyanaa
# Target Correct Word(s): anaawonyanga
# Predicted Word(s): anaawonyanaa
# Is Correct: False
#
# Example 317:
# Incorrect Word(s): egyAouuggya
# Target Correct Word(s): egyAoluggya
# Predicted Word(s): egyAokuggya
# Is Correct: False
#
# Example 318:
# Incorrect Word(s): geAabaddu
# Target Correct Word(s): gyAabaddu
# Predicted Word(s): gwAabaddu
# Is Correct: False
#
# Example 319:
# Incorrect Word(s): okunoiaya
# Target Correct Word(s): okunooaya
# Predicted Word(s): okunolaya
# Is Correct: False
#
# Example 320:
# Incorrect Word(s): omuttnzi
# Target Correct Word(s): omutonzi
# Predicted Word(s): omutunzi
# Is Correct: False
#
# Example 321:
# Incorrect Word(s): nAenkuffizra
# Target Correct Word(s): nAenkuffiira
# Predicted Word(s): nAenkufrizra
# Is Correct: False
#
# Example 322:
# Incorrect Word(s): temunwagiyinza
# Target Correct Word(s): temunnagiyinza
# Predicted Word(s): temunaagiyinza
# Is Correct: False
#
# Example 323:
# Incorrect Word(s): nAamusabar
# Target Correct Word(s): nAamusaba
# Predicted Word(s): nAamusabwe
# Is Correct: False
#
# Example 324:
# Incorrect Word(s): ngAatodde
# Target Correct Word(s): ngAatudde
# Predicted Word(s): ngAatodde
# Is Correct: False
#
# Example 325:
# Incorrect Word(s): bizwibwa
# Target Correct Word(s): bizzibwa
# Predicted Word(s): bizsibwa
# Is Correct: False
#
# Example 326:
# Incorrect Word(s): baxbadde
# Target Correct Word(s): bambadde
# Predicted Word(s): baabadde
# Is Correct: False
#
# Example 327:
# Incorrect Word(s): kirongoofuw
# Target Correct Word(s): kirongoofu
# Predicted Word(s): kirongoofua
# Is Correct: False
#
# Example 328:
# Incorrect Word(s): baatka
# Target Correct Word(s): baatya
# Predicted Word(s): baatka
# Is Correct: False
#
# Example 329:
# Incorrect Word(s): kinauyitangamu
# Target Correct Word(s): kinaayitangamu
# Predicted Word(s): kinauyitangamu
# Is Correct: False
#
# Example 330:
# Incorrect Word(s): ao
# Target Correct Word(s): aa
# Predicted Word(s): zo
# Is Correct: False
#
# Example 331:
# Incorrect Word(s): okuzudkusa
# Target Correct Word(s): okuzuukusa
# Predicted Word(s): okuziduusa
# Is Correct: False
#
# Example 332:
# Incorrect Word(s): oyenkana
# Target Correct Word(s): kyenkana
# Predicted Word(s): oyenkana
# Is Correct: False
#
# Example 333:
# Incorrect Word(s): wakzŋŋaana
# Target Correct Word(s): wakuŋŋaana
# Predicted Word(s): wakaŋŋaana
# Is Correct: False
#
# Example 334:
# Incorrect Word(s): ami
# Target Correct Word(s): am
# Predicted Word(s): ami
# Is Correct: False
#
# Example 335:
# Incorrect Word(s): xzuukiza
# Target Correct Word(s): azuukiza
# Predicted Word(s): azuukiza
# Is Correct: True
#
# Example 336:
# Incorrect Word(s): alirwawa
# Target Correct Word(s): alirwana
# Predicted Word(s): alirwawa
# Is Correct: False
#
# Example 337:
# Incorrect Word(s): kebca
# Target Correct Word(s): kebwa
# Predicted Word(s): kenda
# Is Correct: False
#
# Example 338:
# Incorrect Word(s): naakulayizao
# Target Correct Word(s): naakulayiza
# Predicted Word(s): naakulayizwo
# Is Correct: False
#
# Example 339:
# Incorrect Word(s): eyayogernra
# Target Correct Word(s): eyayogerera
# Predicted Word(s): eyayogeriga
# Is Correct: False
#
# Example 340:
# Incorrect Word(s): tqbaabitegeera
# Target Correct Word(s): tebaabitegeera
# Predicted Word(s): tabaabitereera
# Is Correct: False
#
# Example 341:
# Incorrect Word(s): dAayo
# Target Correct Word(s): nAayo
# Predicted Word(s): zAayo
# Is Correct: False
#
# Example 342:
# Incorrect Word(s): mhasa
# Target Correct Word(s): maasa
# Predicted Word(s): myasa
# Is Correct: False
#
# Example 343:
# Incorrect Word(s): ngAaycma
# Target Correct Word(s): ngAayima
# Predicted Word(s): ngAayama
# Is Correct: False
#
# Example 344:
# Incorrect Word(s): nnzingira
# Target Correct Word(s): nnyingira
# Predicted Word(s): nnzingira
# Is Correct: False
#
# Example 345:
# Incorrect Word(s): nAabatugeeza
# Target Correct Word(s): nAabategeeza
# Predicted Word(s): nAabatugeeza
# Is Correct: False
#
# Example 346:
# Incorrect Word(s): aqigaba
# Target Correct Word(s): aligaba
# Predicted Word(s): asigaba
# Is Correct: False
#
# Example 347:
# Incorrect Word(s): xmimwa
# Target Correct Word(s): emimwa
# Predicted Word(s): amimwa
# Is Correct: False
#
# Example 348:
# Incorrect Word(s): nAatabaljka
# Target Correct Word(s): nAatabaleka
# Predicted Word(s): nAatabalika
# Is Correct: False
#
# Example 349:
# Incorrect Word(s): bAgkkanisa
# Target Correct Word(s): bAekkanisa
# Predicted Word(s): nAekkanisa
# Is Correct: False
#
# Example 350:
# Incorrect Word(s): bakyokyae
# Target Correct Word(s): bakyokya
# Predicted Word(s): bakyokuze
# Is Correct: False
#
# Example 351:
# Incorrect Word(s): jjubird
# Target Correct Word(s): jjubiri
# Predicted Word(s): jjubire
# Is Correct: False
#
# Example 352:
# Incorrect Word(s): egyAomu
# Target Correct Word(s): eryAomu
# Predicted Word(s): egyAomu
# Is Correct: False
#
# Example 353:
# Incorrect Word(s): aligamja
# Target Correct Word(s): aligamba
# Predicted Word(s): aligamja
# Is Correct: False
#
# Example 354:
# Incorrect Word(s): tagulumizibwa
# Target Correct Word(s): bagulumizibwa
# Predicted Word(s): tagulumizibwa
# Is Correct: False
#
# Example 355:
# Incorrect Word(s): eriddac
# Target Correct Word(s): eridda
# Predicted Word(s): eriddae
# Is Correct: False
#
# Example 356:
# Incorrect Word(s): mubima
# Target Correct Word(s): muyima
# Predicted Word(s): mubima
# Is Correct: False
#
# Example 357:
# Incorrect Word(s): balbese
# Target Correct Word(s): baleese
# Predicted Word(s): balbese
# Is Correct: False
#
# Example 358:
# Incorrect Word(s): otuala
# Target Correct Word(s): otwala
# Predicted Word(s): otuala
# Is Correct: False
#
# Example 359:
# Incorrect Word(s): wAeligere
# Target Correct Word(s): wAekigere
# Predicted Word(s): wAekigere
# Is Correct: True
#
# Example 360:
# Incorrect Word(s): gAomusirusifu
# Target Correct Word(s): gAomusirusiru
# Predicted Word(s): nAomusirisivu
# Is Correct: False
#
# Example 361:
# Incorrect Word(s): agAomukosi
# Target Correct Word(s): agAomukozi
# Predicted Word(s): agAomukosi
# Is Correct: False
#
# Example 362:
# Incorrect Word(s): lqnnaalyo
# Target Correct Word(s): linnaalyo
# Predicted Word(s): lannaalyo
# Is Correct: False
#
# Example 363:
# Incorrect Word(s): ezAokgtya
# Target Correct Word(s): ezAokutya
# Predicted Word(s): ezAokutya
# Is Correct: True
#
# Example 364:
# Incorrect Word(s): mubulabye
# Target Correct Word(s): mumulabye
# Predicted Word(s): mubulanye
# Is Correct: False
#
# Example 365:
# Incorrect Word(s): yeetikkj
# Target Correct Word(s): yeetikke
# Predicted Word(s): yeetikki
# Is Correct: False
#
# Example 366:
# Incorrect Word(s): zuyaali
# Target Correct Word(s): zuwaali
# Predicted Word(s): zitaali
# Is Correct: False
#
# Example 367:
# Incorrect Word(s): ntuumuh
# Target Correct Word(s): ntuumu
# Predicted Word(s): ntuumuu
# Is Correct: False
#
# Example 368:
# Incorrect Word(s): ozinyooka
# Target Correct Word(s): ezinyooka
# Predicted Word(s): ozinyooka
# Is Correct: False
#
# Example 369:
# Incorrect Word(s): bampydde
# Target Correct Word(s): bampadde
# Predicted Word(s): bamogdde
# Is Correct: False
#
# Example 370:
# Incorrect Word(s): kqngi
# Target Correct Word(s): kingi
# Predicted Word(s): kangi
# Is Correct: False
#
# Example 371:
# Incorrect Word(s): okumufanga
# Target Correct Word(s): okumulanga
# Predicted Word(s): okumufanga
# Is Correct: False
#
# Example 372:
# Incorrect Word(s): kyAatuulamp
# Target Correct Word(s): kyAatuulamu
# Predicted Word(s): kyAatuulamo
# Is Correct: False
#
# Example 373:
# Incorrect Word(s): onoosimbtnga
# Target Correct Word(s): onoosimbanga
# Predicted Word(s): onoosimbenga
# Is Correct: False
#
# Example 374:
# Incorrect Word(s): nnyoomegwa
# Target Correct Word(s): nnyoomebwa
# Predicted Word(s): nnyoomerwa
# Is Correct: False
#
# Example 375:
# Incorrect Word(s): eryrokubiri
# Target Correct Word(s): eryAokubiri
# Predicted Word(s): eririkubiri
# Is Correct: False
#
# Example 376:
# Incorrect Word(s): zeresy
# Target Correct Word(s): zeresi
# Predicted Word(s): zeresi
# Is Correct: True
#
# Example 377:
# Incorrect Word(s): agoetoolodde
# Target Correct Word(s): ageetoolodde
# Predicted Word(s): agoetoolodde
# Is Correct: False
#
# Example 378:
# Incorrect Word(s): kbri
# Target Correct Word(s): kiri
# Predicted Word(s): obei
# Is Correct: False
#
# Example 379:
# Incorrect Word(s): bay
# Target Correct Word(s): baa
# Predicted Word(s): bat
# Is Correct: False
#
# Example 380:
# Incorrect Word(s): bajjajeange
# Target Correct Word(s): bajjajjange
# Predicted Word(s): bajjajwange
# Is Correct: False
#
# Example 381:
# Incorrect Word(s): abAembkro
# Target Correct Word(s): abAembiro
# Predicted Word(s): abAembiro
# Is Correct: True
#
# Example 382:
# Incorrect Word(s): oyimbale
# Target Correct Word(s): oyambale
# Predicted Word(s): oyimbale
# Is Correct: False
#
# Example 383:
# Incorrect Word(s): kulyopa
# Target Correct Word(s): kulyoka
# Predicted Word(s): kulyola
# Is Correct: False
#
# Example 384:
# Incorrect Word(s): yatuluma
# Target Correct Word(s): yafuluma
# Predicted Word(s): yatuluma
# Is Correct: False
#
# Example 385:
# Incorrect Word(s): nAoyingizb
# Target Correct Word(s): nAoyingiza
# Predicted Word(s): nAoyingize
# Is Correct: False
#
# Example 386:
# Incorrect Word(s): baaaddamu
# Target Correct Word(s): babaddamu
# Predicted Word(s): baaaddamu
# Is Correct: False
#
# Example 387:
# Incorrect Word(s): babituulamw
# Target Correct Word(s): babituulamu
# Predicted Word(s): babituulama
# Is Correct: False
#
# Example 388:
# Incorrect Word(s): tusanyjke
# Target Correct Word(s): tusanyuke
# Predicted Word(s): tusanyuke
# Is Correct: True
#
# Example 389:
# Incorrect Word(s): jalyoka
# Target Correct Word(s): walyoka
# Predicted Word(s): yalyoka
# Is Correct: False
#
# Example 390:
# Incorrect Word(s): libagamua
# Target Correct Word(s): libagamba
# Predicted Word(s): libagamya
# Is Correct: False
#
# Example 391:
# Incorrect Word(s): ngAabuulirirf
# Target Correct Word(s): ngAabuulirira
# Predicted Word(s): ngAabuulirire
# Is Correct: False
#
# Example 392:
# Incorrect Word(s): fyewuunya
# Target Correct Word(s): byewuunya
# Predicted Word(s): eyewuunya
# Is Correct: False
#
# Example 393:
# Incorrect Word(s): agev
# Target Correct Word(s): age
# Predicted Word(s): agee
# Is Correct: False
#
# Example 394:
# Incorrect Word(s): abaasimirwa
# Target Correct Word(s): abaasibirwa
# Predicted Word(s): abaasimirwa
# Is Correct: False
#
# Example 395:
# Incorrect Word(s): muuirumwa
# Target Correct Word(s): mulirumwa
# Predicted Word(s): mukirumwa
# Is Correct: False
#
# Example 396:
# Incorrect Word(s): gaabbe
# Target Correct Word(s): gaabwe
# Predicted Word(s): gaabbe
# Is Correct: False
#
# Example 397:
# Incorrect Word(s): rangai
# Target Correct Word(s): ranga
# Predicted Word(s): tangzi
# Is Correct: False
#
# Example 398:
# Incorrect Word(s): gwagwo
# Target Correct Word(s): gwagwo
# Predicted Word(s): gwagwo
# Is Correct: True
#
# Example 399:
# Incorrect Word(s): wAennanxa
# Target Correct Word(s): wAennanga
# Predicted Word(s): wAennanda
# Is Correct: False
#
# Example 400:
# Incorrect Word(s): ngAakianyumya
# Target Correct Word(s): ngAakyanyumya
# Predicted Word(s): ngAakkanyumya
# Is Correct: False
#
# Example 401:
# Incorrect Word(s): balyonkona
# Target Correct Word(s): balyonoona
# Predicted Word(s): balyonkona
# Is Correct: False
#
# Example 402:
# Incorrect Word(s): nkaabirag
# Target Correct Word(s): nkaabira
# Predicted Word(s): nkaabirae
# Is Correct: False
#
# Example 403:
# Incorrect Word(s): nAobwezingy
# Target Correct Word(s): nAobwezinge
# Predicted Word(s): nAobwezingu
# Is Correct: False
#
# Example 404:
# Incorrect Word(s): olibakolema
# Target Correct Word(s): olibakolera
# Predicted Word(s): olibakolema
# Is Correct: False
#
# Example 405:
# Incorrect Word(s): abasanyuks
# Target Correct Word(s): abasanyuka
# Predicted Word(s): abasanyuka
# Is Correct: True
#
# Example 406:
# Incorrect Word(s): tebakyazanukula
# Target Correct Word(s): tebakyayanukula
# Predicted Word(s): tebakyazanukula
# Is Correct: False
#
# Example 407:
# Incorrect Word(s): uwAasaba
# Target Correct Word(s): bwAasaba
# Predicted Word(s): kwAasaba
# Is Correct: False
#
# Example 408:
# Incorrect Word(s): okugila
# Target Correct Word(s): okugula
# Predicted Word(s): okugola
# Is Correct: False
#
# Example 409:
# Incorrect Word(s): lkimu
# Target Correct Word(s): akimu
# Predicted Word(s): okimu
# Is Correct: False
#
# Example 410:
# Incorrect Word(s): hnnune
# Target Correct Word(s): ennune
# Predicted Word(s): nnnune
# Is Correct: False
#
# Example 411:
# Incorrect Word(s): nalagaala
# Target Correct Word(s): nalagaana
# Predicted Word(s): balagaala
# Is Correct: False
#
# Example 412:
# Incorrect Word(s): kwsimu
# Target Correct Word(s): kusimu
# Predicted Word(s): kasimu
# Is Correct: False
#
# Example 413:
# Incorrect Word(s): binalba
# Target Correct Word(s): binaaba
# Predicted Word(s): binaoba
# Is Correct: False
#
# Example 414:
# Incorrect Word(s): okuyimbax
# Target Correct Word(s): okuyimba
# Predicted Word(s): okuyimbwa
# Is Correct: False
#
# Example 415:
# Incorrect Word(s): nkne
# Target Correct Word(s): nkwe
# Predicted Word(s): kune
# Is Correct: False
#
# Example 416:
# Incorrect Word(s): iubenga
# Target Correct Word(s): tubenga
# Predicted Word(s): kubenga
# Is Correct: False
#
# Example 417:
# Incorrect Word(s): ekikabulwamu
# Target Correct Word(s): ekitabulwamu
# Predicted Word(s): ekikabulwamu
# Is Correct: False
#
# Example 418:
# Incorrect Word(s): busikar
# Target Correct Word(s): busika
# Predicted Word(s): busikae
# Is Correct: False
#
# Example 419:
# Incorrect Word(s): muoaawulira
# Target Correct Word(s): munaawulira
# Predicted Word(s): mulaawulira
# Is Correct: False
#
# Example 420:
# Incorrect Word(s): ekifaagwibwangako
# Target Correct Word(s): ekinaagwibwangako
# Predicted Word(s): ekitaagwibwangako
# Is Correct: False
#
# Example 421:
# Incorrect Word(s): walonda
# Target Correct Word(s): walonda
# Predicted Word(s): walonda
# Is Correct: True
#
# Example 422:
# Incorrect Word(s): alitvnuulira
# Target Correct Word(s): alitunuulira
# Predicted Word(s): alitenuulira
# Is Correct: False
#
# Example 423:
# Incorrect Word(s): abayiseq
# Target Correct Word(s): abayise
# Predicted Word(s): abayissa
# Is Correct: False
#
# Example 424:
# Incorrect Word(s): ofumuvaako
# Target Correct Word(s): okumuvaako
# Predicted Word(s): obumuvaako
# Is Correct: False
#
# Example 425:
# Incorrect Word(s): nnywav
# Target Correct Word(s): nnywa
# Predicted Word(s): nnywae
# Is Correct: False
#
# Example 426:
# Incorrect Word(s): mugguleews
# Target Correct Word(s): mugguleewo
# Predicted Word(s): mugguleewa
# Is Correct: False
#
# Example 427:
# Incorrect Word(s): atabaddev
# Target Correct Word(s): atabadde
# Predicted Word(s): atabaddee
# Is Correct: False
#
# Example 428:
# Incorrect Word(s): mtyinza
# Target Correct Word(s): muyinza
# Predicted Word(s): mtyinza
# Is Correct: False
#
# Example 429:
# Incorrect Word(s): nAebiremaa
# Target Correct Word(s): nAebiremba
# Predicted Word(s): nAebiremwa
# Is Correct: False
#
# Example 430:
# Incorrect Word(s): eyamqkuba
# Target Correct Word(s): eyamukuba
# Predicted Word(s): eyamakuba
# Is Correct: False
#
# Example 431:
# Incorrect Word(s): kyebaqje
# Target Correct Word(s): kyebajje
# Predicted Word(s): kyebaaye
# Is Correct: False
#
# Example 432:
# Incorrect Word(s): abavzaalirwa
# Target Correct Word(s): abaazaalirwa
# Predicted Word(s): ababaaalirwa
# Is Correct: False
#
# Example 433:
# Incorrect Word(s): bAobubiq
# Target Correct Word(s): bAobubi
# Predicted Word(s): nAobubya
# Is Correct: False
#
# Example 434:
# Incorrect Word(s): addanu
# Target Correct Word(s): addamu
# Predicted Word(s): addanu
# Is Correct: False
#
# Example 435:
# Incorrect Word(s): onqogamba
# Target Correct Word(s): onoogamba
# Predicted Word(s): onwogamba
# Is Correct: False
#
# Example 436:
# Incorrect Word(s): nggobuliga
# Target Correct Word(s): ngAobuliga
# Predicted Word(s): nngobulira
# Is Correct: False
#
# Example 437:
# Incorrect Word(s): mumusznze
# Target Correct Word(s): mumusinze
# Predicted Word(s): mumusanze
# Is Correct: False
#
# Example 438:
# Incorrect Word(s): okubafangirira
# Target Correct Word(s): okubatangirira
# Predicted Word(s): okubafangirira
# Is Correct: False
#
# Example 439:
# Incorrect Word(s): n’abot
# Target Correct Word(s): n’abo
# Predicted Word(s): n’abot
# Is Correct: False
#
# Example 440:
# Incorrect Word(s): mbiwaddeo
# Target Correct Word(s): mbiwadde
# Predicted Word(s): mbiwadedo
# Is Correct: False
#
# Example 441:
# Incorrect Word(s): ebisxsunku
# Target Correct Word(s): ebisusunku
# Predicted Word(s): ebisasunku
# Is Correct: False
#
# Example 442:
# Incorrect Word(s): nAayya
# Target Correct Word(s): nAalya
# Predicted Word(s): nAagya
# Is Correct: False
#
# Example 443:
# Incorrect Word(s): kinf
# Target Correct Word(s): kino
# Predicted Word(s): kine
# Is Correct: False
#
# Example 444:
# Incorrect Word(s): nAabatuuva
# Target Correct Word(s): nAabatuusa
# Predicted Word(s): nAabatuuba
# Is Correct: False
#
# Example 445:
# Incorrect Word(s): olwAomontu
# Target Correct Word(s): olwAomuntu
# Predicted Word(s): olwAomuntu
# Is Correct: True
#
# Example 446:
# Incorrect Word(s): ebyAemvrembe
# Target Correct Word(s): ebyAemirembe
# Predicted Word(s): ebyAemdrembe
# Is Correct: False
#
# Example 447:
# Incorrect Word(s): wocya
# Target Correct Word(s): wonya
# Predicted Word(s): wosya
# Is Correct: False
#
# Example 448:
# Incorrect Word(s): alefezanderiya
# Target Correct Word(s): alegezanderiya
# Predicted Word(s): alerezanderiya
# Is Correct: False
#
# Example 449:
# Incorrect Word(s): luriba
# Target Correct Word(s): luliba
# Predicted Word(s): liriba
# Is Correct: False
#
# Example 450:
# Incorrect Word(s): yAobwakobaka
# Target Correct Word(s): yAobwakabaka
# Predicted Word(s): yAobwakobaka
# Is Correct: False
#
# Example 451:
# Incorrect Word(s): nAebyaximbibwa
# Target Correct Word(s): nAebyatimbibwa
# Predicted Word(s): nAebyazimbibwa
# Is Correct: False
#
# Example 452:
# Incorrect Word(s): waleka
# Target Correct Word(s): taleka
# Predicted Word(s): waleka
# Is Correct: False
#
# Example 453:
# Incorrect Word(s): eryalid
# Target Correct Word(s): eryali
# Predicted Word(s): eryalie
# Is Correct: False
#
# Example 454:
# Incorrect Word(s): okulrmusa
# Target Correct Word(s): okulamusa
# Predicted Word(s): okulemusa
# Is Correct: False
#
# Example 455:
# Incorrect Word(s): oddexo
# Target Correct Word(s): oddeyo
# Predicted Word(s): odeeso
# Is Correct: False
#
# Example 456:
# Incorrect Word(s): aliyingirat
# Target Correct Word(s): aliyingira
# Predicted Word(s): aliyingirae
# Is Correct: False
#
# Example 457:
# Incorrect Word(s): nfwebaza
# Target Correct Word(s): nkwebaza
# Predicted Word(s): ntwebaza
# Is Correct: False
#
# Example 458:
# Incorrect Word(s): onox
# Target Correct Word(s): onoo
# Predicted Word(s): onoa
# Is Correct: False
#
# Example 459:
# Incorrect Word(s): ekisara
# Target Correct Word(s): ekisala
# Predicted Word(s): ekisaga
# Is Correct: False
#
# Example 460:
# Incorrect Word(s): anaabaluŋŋamyangf
# Target Correct Word(s): anaabaluŋŋamyanga
# Predicted Word(s): anaabaluŋŋanyange
# Is Correct: False
#
# Example 461:
# Incorrect Word(s): sirowami
# Target Correct Word(s): sirowamu
# Predicted Word(s): sirowami
# Is Correct: False
#
# Example 462:
# Incorrect Word(s): amanyibma
# Target Correct Word(s): amanyibwa
# Predicted Word(s): amanyinma
# Is Correct: False
#
# Example 463:
# Incorrect Word(s): ulirya
# Target Correct Word(s): alirya
# Predicted Word(s): ulirya
# Is Correct: False
#
# Example 464:
# Incorrect Word(s): kyeyonlerenga
# Target Correct Word(s): kyeyongerenga
# Predicted Word(s): kyeyonlerenga
# Is Correct: False
#
# Example 465:
# Incorrect Word(s): nAagitnuma
# Target Correct Word(s): nAagituuma
# Predicted Word(s): nAagituuma
# Is Correct: True
#
# Example 466:
# Incorrect Word(s): ujjuzizza
# Target Correct Word(s): ajjuzizza
# Predicted Word(s): kjjuzizza
# Is Correct: False
#
# Example 467:
# Incorrect Word(s): byAowoze
# Target Correct Word(s): byAokoze
# Predicted Word(s): byAowoze
# Is Correct: False
#
# Example 468:
# Incorrect Word(s): esooka
# Target Correct Word(s): esooka
# Predicted Word(s): esooka
# Is Correct: True
#
# Example 469:
# Incorrect Word(s): olwAenjirik
# Target Correct Word(s): olwAenjiri
# Predicted Word(s): olwAenjirio
# Is Correct: False
#
# Example 470:
# Incorrect Word(s): mbawonyac
# Target Correct Word(s): mbawonya
# Predicted Word(s): mbawonyae
# Is Correct: False
#
# Example 471:
# Incorrect Word(s): lckiiko
# Target Correct Word(s): lukiiko
# Predicted Word(s): lekiiko
# Is Correct: False
#
# Example 472:
# Incorrect Word(s): ndnbakomyawo
# Target Correct Word(s): ndibakomyawo
# Predicted Word(s): ndibakomyawo
# Is Correct: True
#
# Example 473:
# Incorrect Word(s): okiminye
# Target Correct Word(s): okimenye
# Predicted Word(s): okiminye
# Is Correct: False
#
# Example 474:
# Incorrect Word(s): iAayasamya
# Target Correct Word(s): nAayasamya
# Predicted Word(s): nAayasamya
# Is Correct: True
#
# Example 475:
# Incorrect Word(s): nioeeve
# Target Correct Word(s): nineeve
# Predicted Word(s): nooeere
# Is Correct: False
#
# Example 476:
# Incorrect Word(s): zlijjuza
# Target Correct Word(s): alijjuza
# Predicted Word(s): alijjuza
# Is Correct: True
#
# Example 477:
# Incorrect Word(s): eAeddalu
# Target Correct Word(s): nAeddalu
# Predicted Word(s): wAeddalu
# Is Correct: False
#
# Example 478:
# Incorrect Word(s): enzumba
# Target Correct Word(s): ennumba
# Predicted Word(s): enzimba
# Is Correct: False
#
# Example 479:
# Incorrect Word(s): nAokulala
# Target Correct Word(s): nAokulasa
# Predicted Word(s): nAokulala
# Is Correct: False
#
# Example 480:
# Incorrect Word(s): onsansuse
# Target Correct Word(s): onsanyuse
# Predicted Word(s): onwanduse
# Is Correct: False
#
# Example 481:
# Incorrect Word(s): biggweerawx
# Target Correct Word(s): biggweerawo
# Predicted Word(s): biggweerawa
# Is Correct: False
#
# Example 482:
# Incorrect Word(s): nAasimbas
# Target Correct Word(s): nAasimba
# Predicted Word(s): nAasimbwa
# Is Correct: False
#
# Example 483:
# Incorrect Word(s): ngAembuyagao
# Target Correct Word(s): ngAembuyaga
# Predicted Word(s): ngAembuyagao
# Is Correct: False
#
# Example 484:
# Incorrect Word(s): ngAebyAoluberiberye
# Target Correct Word(s): ngAebyAolubereberye
# Predicted Word(s): ngAebyAoluberiberye
# Is Correct: False
#
# Example 485:
# Incorrect Word(s): nAokyamya
# Target Correct Word(s): nAakyamya
# Predicted Word(s): nAokyamya
# Is Correct: False
#
# Example 486:
# Incorrect Word(s): ebyajwa
# Target Correct Word(s): ebyagwa
# Predicted Word(s): ebyamwa
# Is Correct: False
#
# Example 487:
# Incorrect Word(s): abafugaz
# Target Correct Word(s): abafuga
# Predicted Word(s): abafugwa
# Is Correct: False
#
# Example 488:
# Incorrect Word(s): namznya
# Target Correct Word(s): namanya
# Predicted Word(s): bamanya
# Is Correct: False
#
# Example 489:
# Incorrect Word(s): eyAabafirisuuth
# Target Correct Word(s): eyAabafirisuuti
# Predicted Word(s): eyAabafirisuutu
# Is Correct: False
#
# Example 490:
# Incorrect Word(s): fmasanga
# Target Correct Word(s): amasanga
# Predicted Word(s): emasanga
# Is Correct: False
#
# Example 491:
# Incorrect Word(s): samwirq
# Target Correct Word(s): samwiri
# Predicted Word(s): samwira
# Is Correct: False
#
# Example 492:
# Incorrect Word(s): kasirsivu
# Target Correct Word(s): kasiriivu
# Predicted Word(s): kasirsivu
# Is Correct: False
#
# Example 493:
# Incorrect Word(s): yasnokerako
# Target Correct Word(s): yasookerako
# Predicted Word(s): yaanokerako
# Is Correct: False
#
# Example 494:
# Incorrect Word(s): amukumi
# Target Correct Word(s): amakumi
# Predicted Word(s): amukumi
# Is Correct: False
#
# Example 495:
# Incorrect Word(s): nsasonyiwa
# Target Correct Word(s): nAasonyiwa
# Predicted Word(s): nsasonyiwa
# Is Correct: False
#
# Example 496:
# Incorrect Word(s): nnwanj
# Target Correct Word(s): nnwana
# Predicted Word(s): nnaani
# Is Correct: False
#
# Example 497:
# Incorrect Word(s): makuls
# Target Correct Word(s): makulu
# Predicted Word(s): makula
# Is Correct: False
#
# Example 498:
# Incorrect Word(s): yAamaxeeka
# Target Correct Word(s): yAamateeka
# Predicted Word(s): yAamazeeka
# Is Correct: False
#
# Example 499:
# Incorrect Word(s): tabeereoa
# Target Correct Word(s): tabeerera
# Predicted Word(s): tabeereka
# Is Correct: False
#
# Example 500:
# Incorrect Word(s): aueegulumiza
# Target Correct Word(s): ageegulumiza
# Predicted Word(s): ayeegulumiza
# Is Correct: False
#
# Example 501:
# Incorrect Word(s): nAabataans
# Target Correct Word(s): nAabataano
# Predicted Word(s): nAabataana
# Is Correct: False
#
# Example 502:
# Incorrect Word(s): bwAalivaba
# Target Correct Word(s): bwAaliraba
# Predicted Word(s): bwAalibaba
# Is Correct: False
#
# Example 503:
# Incorrect Word(s): ebyeruc
# Target Correct Word(s): ebyeru
# Predicted Word(s): ebyerye
# Is Correct: False
#
# Example 504:
# Incorrect Word(s): cAayigirizanga
# Target Correct Word(s): nAayigirizanga
# Predicted Word(s): zAayigirizanga
# Is Correct: False
#
# Example 505:
# Incorrect Word(s): kikkh
# Target Correct Word(s): kikka
# Predicted Word(s): kikku
# Is Correct: False
#
# Example 506:
# Incorrect Word(s): ndagamba
# Target Correct Word(s): ndigamba
# Predicted Word(s): ndagamba
# Is Correct: False
#
# Example 507:
# Incorrect Word(s): omusunammz
# Target Correct Word(s): omusunammu
# Predicted Word(s): omusunamma
# Is Correct: False
#
# Example 508:
# Incorrect Word(s): uwengayo
# Target Correct Word(s): awengayo
# Predicted Word(s): kwengayo
# Is Correct: False
#
# Example 509:
# Incorrect Word(s): bAomuto
# Target Correct Word(s): nAomuto
# Predicted Word(s): bAomuto
# Is Correct: False
#
# Example 510:
# Incorrect Word(s): temuvumisanga
# Target Correct Word(s): temuvumisanga
# Predicted Word(s): temuvumisanga
# Is Correct: True
#
# Example 511:
# Incorrect Word(s): egydlimu
# Target Correct Word(s): egyalimu
# Predicted Word(s): ebyalimu
# Is Correct: False
#
# Example 512:
# Incorrect Word(s): mukolc
# Target Correct Word(s): mukole
# Predicted Word(s): mukole
# Is Correct: True
#
# Example 513:
# Incorrect Word(s): yaazd
# Target Correct Word(s): yaazo
# Predicted Word(s): yaaze
# Is Correct: False
#
# Example 514:
# Incorrect Word(s): akubooll
# Target Correct Word(s): akubooli
# Predicted Word(s): akuboolo
# Is Correct: False
#
# Example 515:
# Incorrect Word(s): omwenzx
# Target Correct Word(s): omwenzi
# Predicted Word(s): omwenza
# Is Correct: False
#
# Example 516:
# Incorrect Word(s): oyAempewo
# Target Correct Word(s): byAempewo
# Predicted Word(s): kyAempewo
# Is Correct: False
#
# Example 517:
# Incorrect Word(s): yambukam
# Target Correct Word(s): yambuka
# Predicted Word(s): yambukam
# Is Correct: False
#
# Example 518:
# Incorrect Word(s): msaagala
# Target Correct Word(s): ssaagala
# Predicted Word(s): maaagala
# Is Correct: False
#
# Example 519:
# Incorrect Word(s): nAobwoyad
# Target Correct Word(s): nAobwoya
# Predicted Word(s): nAobwoyae
# Is Correct: False
#
# Example 520:
# Incorrect Word(s): nAaddizak
# Target Correct Word(s): nAaddiza
# Predicted Word(s): nAaddizai
# Is Correct: False
#
# Example 521:
# Incorrect Word(s): blAakyukanga
# Target Correct Word(s): bwAakyukanga
# Predicted Word(s): byAakyukanga
# Is Correct: False
#
# Example 522:
# Incorrect Word(s): ulaayii
# Target Correct Word(s): ulaayi
# Predicted Word(s): ulaayli
# Is Correct: False
#
# Example 523:
# Incorrect Word(s): tunaakwytiranga
# Target Correct Word(s): tunaakwatiranga
# Predicted Word(s): tunaakautiranga
# Is Correct: False
#
# Example 524:
# Incorrect Word(s): gyamanyiira
# Target Correct Word(s): eyamanyiira
# Predicted Word(s): gyamanyiira
# Is Correct: False
#
# Example 525:
# Incorrect Word(s): obuloopa
# Target Correct Word(s): okuloopa
# Predicted Word(s): obuloola
# Is Correct: False
#
# Example 526:
# Incorrect Word(s): bkawuka
# Target Correct Word(s): akawuka
# Predicted Word(s): bkawuka
# Is Correct: False
#
# Example 527:
# Incorrect Word(s): secra
# Target Correct Word(s): seera
# Predicted Word(s): seera
# Is Correct: True
#
# Example 528:
# Incorrect Word(s): ecAobubi
# Target Correct Word(s): ezAobubi
# Predicted Word(s): ezAobubi
# Is Correct: True
#
# Example 529:
# Incorrect Word(s): hsaba
# Target Correct Word(s): nsaba
# Predicted Word(s): bsaba
# Is Correct: False
#
# Example 530:
# Incorrect Word(s): ebyAekyamaw
# Target Correct Word(s): ebyAekyama
# Predicted Word(s): ebyAekyamaa
# Is Correct: False
#
# Example 531:
# Incorrect Word(s): nAokjbula
# Target Correct Word(s): nAokubula
# Predicted Word(s): nAokubula
# Is Correct: True
#
# Example 532:
# Incorrect Word(s): nArttira
# Target Correct Word(s): nAattira
# Predicted Word(s): nAettira
# Is Correct: False
#
# Example 533:
# Incorrect Word(s): kxange
# Target Correct Word(s): kwange
# Predicted Word(s): ksange
# Is Correct: False
#
# Example 534:
# Incorrect Word(s): gyAemivulee
# Target Correct Word(s): gyAemivule
# Predicted Word(s): gyAemivulee
# Is Correct: False
#
# Example 535:
# Incorrect Word(s): omwami
# Target Correct Word(s): omwami
# Predicted Word(s): omwami
# Is Correct: True
#
# Example 536:
# Incorrect Word(s): baboogerakox
# Target Correct Word(s): baboogerako
# Predicted Word(s): baboogerakoa
# Is Correct: False
#
# Example 537:
# Incorrect Word(s): munaazikirivanga
# Target Correct Word(s): munaazikiriranga
# Predicted Word(s): munaazikiribanga
# Is Correct: False
#
# Example 538:
# Incorrect Word(s): nAatalekaaso
# Target Correct Word(s): nAatalekaawo
# Predicted Word(s): nAatalekaawo
# Is Correct: True
#
# Example 539:
# Incorrect Word(s): ekiunya
# Target Correct Word(s): ekinnya
# Predicted Word(s): ekiunya
# Is Correct: False
#
# Example 540:
# Incorrect Word(s): ekihone
# Target Correct Word(s): ekitone
# Predicted Word(s): ekitone
# Is Correct: True
#
# Example 541:
# Incorrect Word(s): nAokujeemg
# Target Correct Word(s): nAokujeema
# Predicted Word(s): nAokukeeme
# Is Correct: False
#
# Example 542:
# Incorrect Word(s): bw’atyp
# Target Correct Word(s): bw’atyo
# Predicted Word(s): bw’atyo
# Is Correct: True
#
# Example 543:
# Incorrect Word(s): okusalan
# Target Correct Word(s): okusala
# Predicted Word(s): okusalan
# Is Correct: False
#
# Example 544:
# Incorrect Word(s): yakwutira
# Target Correct Word(s): yakuutira
# Predicted Word(s): yakwutira
# Is Correct: False
#
# Example 545:
# Incorrect Word(s): tosfsola
# Target Correct Word(s): tososola
# Predicted Word(s): tosesola
# Is Correct: False
#
# Example 546:
# Incorrect Word(s): okueungi
# Target Correct Word(s): okulungi
# Predicted Word(s): okusungi
# Is Correct: False
#
# Example 547:
# Incorrect Word(s): okutulumbaq
# Target Correct Word(s): okutulumba
# Predicted Word(s): okutulumbwa
# Is Correct: False
#
# Example 548:
# Incorrect Word(s): ezvengulu
# Target Correct Word(s): ezAengulu
# Predicted Word(s): ezbengulu
# Is Correct: False
#
# Example 549:
# Incorrect Word(s): ikonico
# Target Correct Word(s): ikoniyo
# Predicted Word(s): okoniso
# Is Correct: False
#
# Example 550:
# Incorrect Word(s): ngAalikf
# Target Correct Word(s): ngAaliko
# Predicted Word(s): ngAalike
# Is Correct: False
#
# Example 551:
# Incorrect Word(s): muswya
# Target Correct Word(s): musiya
# Predicted Word(s): musaya
# Is Correct: False
#
# Example 552:
# Incorrect Word(s): olwakae
# Target Correct Word(s): olwaka
# Predicted Word(s): olwakwe
# Is Correct: False
#
# Example 553:
# Incorrect Word(s): avenkana
# Target Correct Word(s): abenkana
# Predicted Word(s): abenkana
# Is Correct: True
#
# Example 554:
# Incorrect Word(s): kizze
# Target Correct Word(s): kizze
# Predicted Word(s): kizze
# Is Correct: True
#
# Example 555:
# Incorrect Word(s): atayimusdnga
# Target Correct Word(s): atayimusanga
# ...
#
# Example 872:
# Incorrect Word(s): batusfmbeza
# Target Correct Word(s): batusembeza
# Predicted Word(s): batusembeza
# Is Correct: True
#
# Example 873:
# Incorrect Word(s): exibaddeyo
# Target Correct Word(s): ebibaddeyo
# Predicted Word(s): ezibaddeyo
# Is Correct: False
#
# Example 874:
# Incorrect Word(s): olwAenkyad
# Target Correct Word(s): olwAenkya
# Predicted Word(s): olwAenkyze
# Is Correct: False
#
# Example 875:
# Incorrect Word(s): gAegyo
# Target Correct Word(s): gAebyo
# Predicted Word(s): nAebyo
# Is Correct: False
#
# Example 876:
# Incorrect Word(s): yekinso
# Target Correct Word(s): yakinso
# Predicted Word(s): yekindo
# Is Correct: False
#
# Example 877:
# Incorrect Word(s): amasongezob
# Target Correct Word(s): amasongezo
# Predicted Word(s): amasongezoe
# Is Correct: False
#
# Example 878:
# Incorrect Word(s): teyandigese
# Target Correct Word(s): teyandirese
# Predicted Word(s): teyandigese
# Is Correct: False
#
# Example 879:
# Incorrect Word(s): nAolwAokusanyufirako
# Target Correct Word(s): nAolwAokusanyukirako
# Predicted Word(s): nAolwAokusanyurirako
# Is Correct: False
#
# Example 880:
# Incorrect Word(s): waalmwo
# Target Correct Word(s): waaliwo
# Predicted Word(s): wazimwo
# Is Correct: False
#
# Example 881:
# Incorrect Word(s): mateeka
# Target Correct Word(s): wateeka
# Predicted Word(s): mateeka
# Is Correct: False
#
# Example 882:
# Incorrect Word(s): egguufiro
# Target Correct Word(s): egguuliro
# Predicted Word(s): enguufiro
# Is Correct: False
#
# Example 883:
# Incorrect Word(s): anolodde
# Target Correct Word(s): agolodde
# Predicted Word(s): abolodde
# Is Correct: False
#
# Example 884:
# Incorrect Word(s): bwAebab
# Target Correct Word(s): bwAeba
# Predicted Word(s): bwAebab
# Is Correct: False
#
# Example 885:
# Incorrect Word(s): ewatika
# Target Correct Word(s): lwatika
# Predicted Word(s): ewatika
# Is Correct: False
#
# Example 886:
# Incorrect Word(s): banoonya
# Target Correct Word(s): banoonya
# Predicted Word(s): banoonya
# Is Correct: True
#
# Example 887:
# Incorrect Word(s): ngAennangrazi
# Target Correct Word(s): ngAennangaazi
# Predicted Word(s): ngAennangrazi
# Is Correct: False
#
# Example 888:
# Incorrect Word(s): eyAemdaga
# Target Correct Word(s): eyAembaga
# Predicted Word(s): eyAemdaga
# Is Correct: False
#
# Example 889:
# Incorrect Word(s): ogwAokutegeeraf
# Target Correct Word(s): ogwAokutegeera
# Predicted Word(s): ogwAokutegeerae
# Is Correct: False
#
# Example 890:
# Incorrect Word(s): ogatter
# Target Correct Word(s): ogatte
# Predicted Word(s): ogattee
# Is Correct: False
#
# Example 891:
# Incorrect Word(s): kyAabadje
# Target Correct Word(s): kyAabadde
# Predicted Word(s): kyAabadye
# Is Correct: False
#
# Example 892:
# Incorrect Word(s): klsanvu
# Target Correct Word(s): kasanvu
# Predicted Word(s): kisanvu
# Is Correct: False
#
# Example 893:
# Incorrect Word(s): ezaavn
# Target Correct Word(s): ezaava
# Predicted Word(s): ezaavu
# Is Correct: False
#
# Example 894:
# Incorrect Word(s): ensuto
# Target Correct Word(s): ensulo
# Predicted Word(s): ensuto
# Is Correct: False
#
# Example 895:
# Incorrect Word(s): abakuhma
# Target Correct Word(s): abakuuma
# Predicted Word(s): abakuuma
# Is Correct: True
#
# Example 896:
# Incorrect Word(s): oziteeka
# Target Correct Word(s): oliteeka
# Predicted Word(s): oziteeka
# Is Correct: False
#
# Example 897:
# Incorrect Word(s): kulwbeera
# Target Correct Word(s): kulibeera
# Predicted Word(s): kulabeera
# Is Correct: False
#
# Example 898:
# Incorrect Word(s): akjokuna
# Target Correct Word(s): akAokuna
# Predicted Word(s): akjokuna
# Is Correct: False
#
# Example 899:
# Incorrect Word(s): vireme
# Target Correct Word(s): zireme
# Predicted Word(s): bireme
# Is Correct: False
#
# Example 900:
# Incorrect Word(s): nnawrlirira
# Target Correct Word(s): nnawulirira
# Predicted Word(s): nnawelirira
# Is Correct: False
#
# Example 901:
# Incorrect Word(s): kubagksa
# Target Correct Word(s): kubagasa
# Predicted Word(s): kubagusa
# Is Correct: False
#
# Example 902:
# Incorrect Word(s): nAokubeeraliikirzza
# Target Correct Word(s): nAokubeeraliikiriza
# Predicted Word(s): nAokubeeraliikirzza
# Is Correct: False
#
# Example 903:
# Incorrect Word(s): alincwa
# Target Correct Word(s): alinywa
# Predicted Word(s): alindwa
# Is Correct: False
#
# Example 904:
# Incorrect Word(s): ekwayogererwa
# Target Correct Word(s): ekyayogererwa
# Predicted Word(s): ekwayogererwa
# Is Correct: False
#
# Example 905:
# Incorrect Word(s): bakasirut
# Target Correct Word(s): bakasiru
# Predicted Word(s): bakasirue
# Is Correct: False
#
# Example 906:
# Incorrect Word(s): ndisanyuklra
# Target Correct Word(s): ndisanyukira
# Predicted Word(s): ndisanyukira
# Is Correct: True
#
# Example 907:
# Incorrect Word(s): zalesdni
# Target Correct Word(s): zalesani
# Predicted Word(s): zaleseni
# Is Correct: False
#
# Example 908:
# Incorrect Word(s): bAewaabwev
# Target Correct Word(s): bAewaabwe
# Predicted Word(s): nAewaabwee
# Is Correct: False
#
# Example 909:
# Incorrect Word(s): bwwunama
# Target Correct Word(s): bawunama
# Predicted Word(s): bawunama
# Is Correct: True
#
# Example 910:
# Incorrect Word(s): nAagatra
# Target Correct Word(s): nAagatta
# Predicted Word(s): nAabatra
# Is Correct: False
#
# Example 911:
# Incorrect Word(s): basbma
# Target Correct Word(s): basima
# Predicted Word(s): basnma
# Is Correct: False
#
# Example 912:
# Incorrect Word(s): bankuŋŋaanprako
# Target Correct Word(s): bankuŋŋaanirako
# Predicted Word(s): bankuŋŋaanirako
# Is Correct: True
#
# Example 913:
# Incorrect Word(s): wafulemamu
# Target Correct Word(s): wafulumamu
# Predicted Word(s): wafulemamu
# Is Correct: False
#
# Example 914:
# Incorrect Word(s): wAomuzabhibu
# Target Correct Word(s): wAomuzabbibu
# Predicted Word(s): wAomuzanyibu
# Is Correct: False
#
# Example 915:
# Incorrect Word(s): omusanpu
# Target Correct Word(s): omusanvu
# Predicted Word(s): omusanlu
# Is Correct: False
#
# Example 916:
# Incorrect Word(s): bamgleetera
# Target Correct Word(s): bamuleetera
# Predicted Word(s): bamuleetera
# Is Correct: True
#
# Example 917:
# Incorrect Word(s): matwale
# Target Correct Word(s): matwale
# Predicted Word(s): mataale
# Is Correct: False
#
# Example 918:
# Incorrect Word(s): ekyAamalibac
# Target Correct Word(s): ekyAamaliba
# Predicted Word(s): ekyAamalibwe
# Is Correct: False
#
# Example 919:
# Incorrect Word(s): aAeznyumba
# Target Correct Word(s): aAennyumba
# Predicted Word(s): wAeznyumba
# Is Correct: False
#
# Example 920:
# Incorrect Word(s): ngAevazyo
# Target Correct Word(s): ngAevaayo
# Predicted Word(s): ngAebaayo
# Is Correct: False
#
# Example 921:
# Incorrect Word(s): nbembazzi
# Target Correct Word(s): nAembazzi
# Predicted Word(s): nnembazzi
# Is Correct: False
#
# Example 922:
# Incorrect Word(s): obukovvz
# Target Correct Word(s): obukovvu
# Predicted Word(s): obukobba
# Is Correct: False
#
# Example 923:
# Incorrect Word(s): balwanyisau
# Target Correct Word(s): balwanyisa
# Predicted Word(s): balwanyisau
# Is Correct: False
#
# Example 924:
# Incorrect Word(s): yalamuyi
# Target Correct Word(s): yalamusi
# Predicted Word(s): yalamuyi
# Is Correct: False
#
# Example 925:
# Incorrect Word(s): okubayingkza
# Target Correct Word(s): okubayingiza
# Predicted Word(s): okubayingiza
# Is Correct: True
#
# Example 926:
# Incorrect Word(s): abalituula
# Target Correct Word(s): abalituula
# Predicted Word(s): abalituula
# Is Correct: True
#
# Example 927:
# Incorrect Word(s): eyAekkomeka
# Target Correct Word(s): eyAekkomera
# Predicted Word(s): eyAekkomeka
# Is Correct: False
#
# Example 928:
# Incorrect Word(s): oeuwazi
# Target Correct Word(s): omuwazi
# Predicted Word(s): osuwazi
# Is Correct: False
#
# Example 929:
# Incorrect Word(s): nAakubibca
# Target Correct Word(s): nAakubibwa
# Predicted Word(s): nAakubinwa
# Is Correct: False
#
# Example 930:
# Incorrect Word(s): tulwanal
# Target Correct Word(s): tulwana
# Predicted Word(s): tulwanzi
# Is Correct: False
#
# Example 931:
# Incorrect Word(s): zwokka
# Target Correct Word(s): mwokka
# Predicted Word(s): zwokka
# Is Correct: False
#
# Example 932:
# Incorrect Word(s): mugoxokofu
# Target Correct Word(s): mugolokofu
# Predicted Word(s): mugosokofu
# Is Correct: False
#
# Example 933:
# Incorrect Word(s): aunene
# Target Correct Word(s): bunene
# Predicted Word(s): sunene
# Is Correct: False
#
# Example 934:
# Incorrect Word(s): nganyweza
# Target Correct Word(s): nAanyweza
# Predicted Word(s): nnanyweza
# Is Correct: False
#
# Example 935:
# Incorrect Word(s): gwAewenma
# Target Correct Word(s): gwAeweema
# Predicted Word(s): gwAewenga
# Is Correct: False
#
# Example 936:
# Incorrect Word(s): obukumic
# Target Correct Word(s): obukumi
# Predicted Word(s): obukumie
# Is Correct: False
#
# Example 937:
# Incorrect Word(s): odAamaanyi
# Target Correct Word(s): owAamaanyi
# Predicted Word(s): owAamaanyi
# Is Correct: True
#
# Example 938:
# Incorrect Word(s): olewu
# Target Correct Word(s): olebu
# Predicted Word(s): olewu
# Is Correct: False
#
# Example 939:
# Incorrect Word(s): birimaha
# Target Correct Word(s): birimala
# Predicted Word(s): birimana
# Is Correct: False
#
# Example 940:
# Incorrect Word(s): ndisenya
# Target Correct Word(s): ndinenya
# Predicted Word(s): ndisenya
# Is Correct: False
#
# Example 941:
# Incorrect Word(s): ebingya
# Target Correct Word(s): ebinnya
# Predicted Word(s): ebingya
# Is Correct: False
#
# Example 942:
# Incorrect Word(s): ebikwxlesebwa
# Target Correct Word(s): ebikwolesebwa
# Predicted Word(s): ebikwalesebwa
# Is Correct: False
#
# Example 943:
# Incorrect Word(s): emikuufuf
# Target Correct Word(s): emikuufu
# Predicted Word(s): emikuufue
# Is Correct: False
#
# Example 944:
# Incorrect Word(s): asyusizza
# Target Correct Word(s): akyusizza
# Predicted Word(s): asuusizza
# Is Correct: False
#
# Example 945:
# Incorrect Word(s): awuliddu
# Target Correct Word(s): awulidde
# Predicted Word(s): awuliddu
# Is Correct: False
#
# Example 946:
# Incorrect Word(s): luoimba
# Target Correct Word(s): lusimba
# Predicted Word(s): lulimba
# Is Correct: False
#
# Example 947:
# Incorrect Word(s): ndinerengeta
# Target Correct Word(s): ndiserengeta
# Predicted Word(s): ndinerengera
# Is Correct: False
#
# Example 948:
# Incorrect Word(s): kyAamatofdaali
# Target Correct Word(s): kyAamatoffaali
# Predicted Word(s): kyAamatoddaali
# Is Correct: False
#
# Example 949:
# Incorrect Word(s): gambanka
# Target Correct Word(s): gambanga
# Predicted Word(s): gambanka
# Is Correct: False
#
# Example 950:
# Incorrect Word(s): eyasalibwakom
# Target Correct Word(s): eyasalibwako
# Predicted Word(s): eyasalibwakom
# Is Correct: False
#
# Example 951:
# Incorrect Word(s): kutiangac
# Target Correct Word(s): kutianga
# Predicted Word(s): kutiangwe
# Is Correct: False
#
# Example 952:
# Incorrect Word(s): kafudde
# Target Correct Word(s): kufudde
# Predicted Word(s): kafudde
# Is Correct: False
#
# Example 953:
# Incorrect Word(s): nAayolesz
# Target Correct Word(s): nAayolesa
# Predicted Word(s): nAayolesa
# Is Correct: True
#
# Example 954:
# Incorrect Word(s): nAdŋŋamira
# Target Correct Word(s): nAeŋŋamira
# Predicted Word(s): nAeŋŋamira
# Is Correct: True
#
# Example 955:
# Incorrect Word(s): luaama
# Target Correct Word(s): lukama
# Predicted Word(s): lusama
# Is Correct: False
#
# Example 956:
# Incorrect Word(s): kwAemiywa
# Target Correct Word(s): kwAemimwa
# Predicted Word(s): kwAemitwa
# Is Correct: False
#
# Example 957:
# Incorrect Word(s): bwAayerx
# Target Correct Word(s): bwAayera
# Predicted Word(s): bwAayera
# Is Correct: True
#
# Example 958:
# Incorrect Word(s): lfnaatera
# Target Correct Word(s): lunaatera
# Predicted Word(s): lenaatera
# Is Correct: False
#
# Example 959:
# Incorrect Word(s): tebawasn
# Target Correct Word(s): tebawasa
# Predicted Word(s): tebawasi
# Is Correct: False
#
# Example 960:
# Incorrect Word(s): tskuli
# Target Correct Word(s): tekuli
# Predicted Word(s): tekuli
# Is Correct: True
#
# Example 961:
# Incorrect Word(s): sajjajjaa
# Target Correct Word(s): bajjajjaa
# Predicted Word(s): sajjajjza
# Is Correct: False
#
# Example 962:
# Incorrect Word(s): kizikzza
# Target Correct Word(s): kizikiza
# Predicted Word(s): kizikzza
# Is Correct: False
#
# Example 963:
# Incorrect Word(s): ebybgunjibwa
# Target Correct Word(s): ebyagunjibwa
# Predicted Word(s): ebingunyibwa
# Is Correct: False
#
# Example 964:
# Incorrect Word(s): amuyitaw
# Target Correct Word(s): amuyita
# Predicted Word(s): amuyitaa
# Is Correct: False
#
# Example 965:
# Incorrect Word(s): seguuu
# Target Correct Word(s): segubu
# Predicted Word(s): segumu
# Is Correct: False
#
# Example 966:
# Incorrect Word(s): nAtbasabira
# Target Correct Word(s): nAabasabira
# Predicted Word(s): nAebasabira
# Is Correct: False
#
# Example 967:
# Incorrect Word(s): yabeerangcmu
# Target Correct Word(s): yabeerangamu
# Predicted Word(s): yabeerangamu
# Is Correct: True
#
# Example 968:
# Incorrect Word(s): bisuuiya
# Target Correct Word(s): bisuniya
# Predicted Word(s): bisuulya
# Is Correct: False
#
# Example 969:
# Incorrect Word(s): bbulabi
# Target Correct Word(s): obulabi
# Predicted Word(s): ebulabi
# Is Correct: False
#
# Example 970:
# Incorrect Word(s): tujiba
# Target Correct Word(s): tuliba
# Predicted Word(s): tukiba
# Is Correct: False
#
# Example 971:
# Incorrect Word(s): nhemuluma
# Target Correct Word(s): nAemuluma
# Predicted Word(s): nnemuluma
# Is Correct: False
#
# Example 972:
# Incorrect Word(s): yagulira
# Target Correct Word(s): yajulira
# Predicted Word(s): yagulira
# Is Correct: False
#
# Example 973:
# Incorrect Word(s): batjeemera
# Target Correct Word(s): banjeemera
# Predicted Word(s): batueemera
# Is Correct: False
#
# Example 974:
# Incorrect Word(s): nkwatai
# Target Correct Word(s): nkwata
# Predicted Word(s): nkwatzi
# Is Correct: False
#
# Example 975:
# Incorrect Word(s): wansinsx
# Target Correct Word(s): wansinsi
# Predicted Word(s): wansinda
# Is Correct: False
#
# Example 976:
# Incorrect Word(s): alooaiq
# Target Correct Word(s): alooai
# Predicted Word(s): alooala
# Is Correct: False
#
# Example 977:
# Incorrect Word(s): tegau
# Target Correct Word(s): tega
# Predicted Word(s): tenzi
# Is Correct: False
#
# Example 978:
# Incorrect Word(s): bafugax
# Target Correct Word(s): bafuga
# Predicted Word(s): bafugwa
# Is Correct: False
#
# Example 979:
# Incorrect Word(s): gAennyanka
# Target Correct Word(s): gAennyanja
# Predicted Word(s): nAennyanka
# Is Correct: False
#
# Example 980:
# Incorrect Word(s): bwnennyama
# Target Correct Word(s): bwAennyama
# Predicted Word(s): banennyama
# Is Correct: False
#
# Example 981:
# Incorrect Word(s): ezAensondal
# Target Correct Word(s): ezAensonda
# Predicted Word(s): ezAensondao
# Is Correct: False
#
# Example 982:
# Incorrect Word(s): nteesezzat
# Target Correct Word(s): nteesezza
# Predicted Word(s): nteesezzae
# Is Correct: False
#
# Example 983:
# Incorrect Word(s): cAenku
# Target Correct Word(s): nAenku
# Predicted Word(s): zAenku
# Is Correct: False
#
# Example 984:
# Incorrect Word(s): bwAalijjq
# Target Correct Word(s): bwAalijja
# Predicted Word(s): bwAalijja
# Is Correct: True
#
# Example 985:
# Incorrect Word(s): gbyAoku
# Target Correct Word(s): ebyAoku
# Predicted Word(s): ebyAoku
# Is Correct: True
#
# Example 986:
# Incorrect Word(s): asumlibwa
# Target Correct Word(s): asuulibwa
# Predicted Word(s): asumlibwa
# Is Correct: False
#
# Example 987:
# Incorrect Word(s): gaggweererax
# Target Correct Word(s): gaggweerera
# Predicted Word(s): baggweererwa
# Is Correct: False
#
# Example 988:
# Incorrect Word(s): waknsa
# Target Correct Word(s): wakisa
# Predicted Word(s): waknsa
# Is Correct: False
#
# Example 989:
# Incorrect Word(s): gayimgsizza
# Target Correct Word(s): gayimusizza
# Predicted Word(s): bayimusizza
# Is Correct: False
#
# Example 990:
# Incorrect Word(s): nAeddoxoozi
# Target Correct Word(s): nAeddoboozi
# Predicted Word(s): nAeddozoozi
# Is Correct: False
#
# Example 991:
# Incorrect Word(s): gyArwaayo
# Target Correct Word(s): gyAawaayo
# Predicted Word(s): gyAewaayo
# Is Correct: False
#
# Example 992:
# Incorrect Word(s): agAempologima
# Target Correct Word(s): agAempologoma
# Predicted Word(s): agAempologima
# Is Correct: False
#
# Example 993:
# Incorrect Word(s): bwAaliweebwa
# Target Correct Word(s): bwAaliweebwa
# Predicted Word(s): bwAaliweebwa
# Is Correct: True
#
# Example 994:
# Incorrect Word(s): musate
# Target Correct Word(s): musabe
# Predicted Word(s): musate
# Is Correct: False
#
# Example 995:
# Incorrect Word(s): okungwanga
# Target Correct Word(s): okunywanga
# Predicted Word(s): okungwanga
# Is Correct: False
#
# Example 996:
# Incorrect Word(s): steeketeeke
# Target Correct Word(s): oteeketeeke
# Predicted Word(s): eteeketeeke
# Is Correct: False
#
# Example 997:
# Incorrect Word(s): nAatonna
# Target Correct Word(s): nAatonda
# Predicted Word(s): nAayonna
# Is Correct: False
#
# Example 998:
# Incorrect Word(s): kwAehsi
# Target Correct Word(s): kwAensi
# Predicted Word(s): kwAensi
# Is Correct: True
#
# Example 999:
# Incorrect Word(s): totabiala
# Target Correct Word(s): totabaala
# Predicted Word(s): totabiala
# Is Correct: False
#
# Example 1000:
# Incorrect Word(s): bylagira
# Target Correct Word(s): balagira
# Predicted Word(s): bulagira
# Is Correct: False
